# %% [markdown]
# # Training a microWakeWord Model
#
# This notebook steps you through training a basic microWakeWord model. It is intended as a **starting point** for advanced users. You should use Python 3.10.
#
# **The model generated will most likely not be usable for everyday use; it may be difficult to trigger or falsely activates too frequently. You will most likely have to experiment with many different settings to obtain a decent model!**
#
# In the comment at the start of certain blocks, I note some specific settings to consider modifying.
#
# This runs on Google Colab, but is extremely slow compared to training on a local GPU. If you must use Colab, be sure to Change the runtime type to a GPU. Even then, it still slow!
#
# At the end of this notebook, you will be able to download a tflite file. To use this in ESPHome, you need to write a model manifest JSON file. See the [ESPHome documentation](https://esphome.io/components/micro_wake_word) for the details and the [model repo](https://github.com/esphome/micro-wake-word-models/tree/main/models/v2) for examples.

# %%
# Installs microWakeWord. Be sure to restart the session after this is finished.
import platform

if platform.system() == "Darwin":
    # `pymicro-features` is installed from a fork to support building on macOS
    # !pip install 'git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version'

# `audio-metadata` is installed from a fork to unpin `attrs` from a version that breaks Jupyter
# !pip install 'git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'

# !git clone https://github.com/kahrendt/microWakeWord
# !pip install -e ./microWakeWord
# Out:
# Collecting git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Cloning https://github.com/whatsnowplaying/audio-metadata (to revision d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f) to /tmp/pip-req-build-osxz80cf
#   Running command git clone --filter=blob:none --quiet https://github.com/whatsnowplaying/audio-metadata /tmp/pip-req-build-osxz80cf
#   Running command git rev-parse -q --verify 'sha^d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'
#   Running command git fetch -q https://github.com/whatsnowplaying/audio-metadata d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Running command git checkout -q d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Resolved https://github.com/whatsnowplaying/audio-metadata to commit d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=18.2 in /usr/local/lib/python3.13/dist-packages (from audio-metadata==0.12.0) (26.1.0)
# Collecting bidict==0.* (from audio-metadata==0.12.0)
#   Downloading bidict-0.24.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting bitstruct<9.0,>=6.0 (from audio-metadata==0.12.0)
#   Downloading bitstruct-8.23.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (7.3 kB)
# Collecting more-itertools<9.0,>=4.0 (from audio-metadata==0.12.0)
#   Downloading more_itertools-8.14.0-py3-none-any.whl.metadata (30 kB)
# Collecting pprintpp==0.* (from audio-metadata==0.12.0)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting wrapt<2.0,>=1.0 (from audio-metadata==0.12.0)
#   Downloading wrapt-1.17.3-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Downloading bidict-0.24.1-py3-none-any.whl (36 kB)
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading bitstruct-8.23.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 4.1 MB/s eta 0:00:00
# Downloading more_itertools-8.14.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 4.4 MB/s eta 0:00:00
# Downloading wrapt-1.17.3-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 9.7 MB/s eta 0:00:00
# Building wheels for collected packages: audio-metadata
#   Building wheel for audio-metadata (pyproject.toml) ... done
#   Created wheel for audio-metadata: filename=audio_metadata-0.12.0-py3-none-any.whl size=53185 sha256=c5ed75ab41e83e18dad211329e7fa4e05c497e304ad1d41a3d26920440a581a6
#   Stored in directory: /root/.cache/pip/wheels/77/b8/8c/b5ae90e37fc3fa5444b07969b29b3b5758df77c3852e13edeb
# Successfully built audio-metadata
# Installing collected packages: pprintpp, wrapt, more-itertools, bitstruct, bidict, audio-metadata
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.4.0
#     Uninstalling wrapt-2.4.0:
#       Successfully uninstalled wrapt-2.4.0
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 10.8.0
#     Uninstalling more-itertools-10.8.0:
#       Successfully uninstalled more-itertools-10.8.0
# Successfully installed audio-metadata-0.12.0 bidict-0.24.1 bitstruct-8.23.0 more-itertools-8.14.0 pprintpp-0.4.0 wrapt-1.17.3
# Cloning into 'microWakeWord'...
# remote: Enumerating objects: 631, done.
# remote: Total 631 (delta 0), reused 0 (delta 0), pack-reused 631 (from 1)
# Receiving objects: 100% (631/631), 664.43 KiB | 21.43 MiB/s, done.
# Resolving deltas: 100% (370/370), done.
# Obtaining file:///content/microWakeWord
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting audiomentations (from microwakeword==0.1.0)
#   Downloading audiomentations-0.43.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: audio_metadata in /usr/local/lib/python3.13/dist-packages (from microwakeword==0.1.0) (0.12.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.13/dist-packages (from microwakeword==0.1.0) (4.8.5)
# Collecting mmap_ninja (from microwakeword==0.1.0)
#   Downloading mmap_ninja-0.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.13/dist-packages (from microwakeword==0.1.0) (2.1.3)
# Collecting pymicro-features (from microwakeword==0.1.0)
#   Downloading pymicro_features-2.0.2-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from microwakeword==0.1.0) (6.0.3)
# Requirement already satisfied: tensorflow>=2.18 in /usr/local/lib/python3.13/dist-packages (from microwakeword==0.1.0) (2.20.0)
# Collecting webrtcvad-wheels (from microwakeword==0.1.0)
#   Downloading webrtcvad_wheels-2.0.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting ai-edge-litert (from microwakeword==0.1.0)
#   Downloading ai_edge_litert-2.2.0-cp313-cp313-manylinux_2_27_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (26.3)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (1.83.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow>=2.18->microwakeword==0.1.0) (0.6.0)
# Collecting backports.strenum (from ai-edge-litert->microwakeword==0.1.0)
#   Downloading backports_strenum-1.2.8-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from ai-edge-litert->microwakeword==0.1.0) (4.67.3)
# Requirement already satisfied: attrs>=18.2 in /usr/local/lib/python3.13/dist-packages (from audio_metadata->microwakeword==0.1.0) (26.1.0)
# Requirement already satisfied: bidict==0.* in /usr/local/lib/python3.13/dist-packages (from audio_metadata->microwakeword==0.1.0) (0.24.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /usr/local/lib/python3.13/dist-packages (from audio_metadata->microwakeword==0.1.0) (8.23.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /usr/local/lib/python3.13/dist-packages (from audio_metadata->microwakeword==0.1.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /usr/local/lib/python3.13/dist-packages (from audio_metadata->microwakeword==0.1.0) (0.4.0)
# Collecting numpy-minmax<1,>=0.3.0 (from audiomentations->microwakeword==0.1.0)
#   Downloading numpy_minmax-0.6.0-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (4.1 kB)
# Collecting numpy-rms<1,>=0.4.2 (from audiomentations->microwakeword==0.1.0)
#   Downloading numpy_rms-0.7.0-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: librosa!=0.10.0,<0.12.0,>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations->microwakeword==0.1.0) (0.11.0)
# Collecting python-stretch<1,>=0.3.1 (from audiomentations->microwakeword==0.1.0)
#   Downloading python_stretch-0.3.1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: scipy<2,>=1.4 in /usr/local/lib/python3.13/dist-packages (from audiomentations->microwakeword==0.1.0) (1.16.3)
# Collecting soxr<1.0.0,>=0.3.2 (from audiomentations->microwakeword==0.1.0)
#   Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (3.32.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2025.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from datasets->microwakeword==0.1.0) (1.29.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from astunparse>=1.6.0->tensorflow>=2.18->microwakeword==0.1.0) (0.48.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->microwakeword==0.1.0) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->microwakeword==0.1.0) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->microwakeword==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->microwakeword==0.1.0) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets->microwakeword==0.1.0) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets->microwakeword==0.1.0) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets->microwakeword==0.1.0) (1.6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (0.20.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.61.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.14.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.9.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.2.2)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.13.0)
# Requirement already satisfied: standard-sunau in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.13.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (2.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.18->microwakeword==0.1.0) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.18->microwakeword==0.1.0) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.18->microwakeword==0.1.0) (3.10.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.18->microwakeword==0.1.0) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.18->microwakeword==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.18->microwakeword==0.1.0) (3.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets->microwakeword==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets->microwakeword==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets->microwakeword==0.1.0) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.24.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (3.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.1.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.51.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (4.11.7)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.6.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow>=2.18->microwakeword==0.1.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (2.21.0)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from standard-aifc->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=2.18->microwakeword==0.1.0) (0.1.2)
# Downloading ai_edge_litert-2.2.0-cp313-cp313-manylinux_2_27_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 76.7 MB/s eta 0:00:00
# Downloading audiomentations-0.43.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 9.8 MB/s eta 0:00:00
# Downloading mmap_ninja-0.9.0-py3-none-any.whl (17 kB)
# Downloading pymicro_features-2.0.2-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.6/119.6 kB 10.2 MB/s eta 0:00:00
# Downloading webrtcvad_wheels-2.0.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.9 MB/s eta 0:00:00
# Downloading numpy_minmax-0.6.0-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (27 kB)
# Downloading numpy_rms-0.7.0-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (17 kB)
# Downloading python_stretch-0.3.1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 9.8 MB/s eta 0:00:00
# Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (248 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 26.7 MB/s eta 0:00:00
# Downloading backports_strenum-1.2.8-py3-none-any.whl (7.9 kB)
# Building wheels for collected packages: microwakeword
#   Building editable for microwakeword (pyproject.toml) ... done
#   Created wheel for microwakeword: filename=microwakeword-0.1.0-0.editable-py3-none-any.whl size=9939 sha256=53092be5cbe21f8e12e3b6a5745ca1dcfeb61bdfff9119c00a293f50eeb672b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iffloay9/wheels/e6/4d/9d/aaef2390a3e555f0f2503fb025613fbc84450e4c7545db6d12
# Successfully built microwakeword
# Installing collected packages: webrtcvad-wheels, soxr, python-stretch, pymicro-features, mmap_ninja, backports.strenum, numpy-rms, numpy-minmax, ai-edge-litert, audiomentations, microwakeword
#   Attempting uninstall: soxr
#     Found existing installation: soxr 1.1.0
#     Uninstalling soxr-1.1.0:
#       Successfully uninstalled soxr-1.1.0
# Successfully installed ai-edge-litert-2.2.0 audiomentations-0.43.1 backports.strenum-1.2.8 microwakeword-0.1.0 mmap_ninja-0.9.0 numpy-minmax-0.6.0 numpy-rms-0.7.0 pymicro-features-2.0.2 python-stretch-0.3.1 soxr-0.5.0.post1 webrtcvad-wheels-2.0.14

# %%
# Generates 1 sample of the target word for manual verification.

target_word = 'khum_puter'  # Phonetic spellings may produce better samples

import os
import sys
import platform

from IPython.display import Audio

if not os.path.exists("./piper-sample-generator"):
    if platform.system() == "Darwin":
        # !git clone -b mps-support https://github.com/kahrendt/piper-sample-generator
    else:
        # !git clone https://github.com/rhasspy/piper-sample-generator

    # !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'

    # Install system dependencies
    # !pip install torch torchaudio piper-phonemize-cross==1.2.1

    if "piper-sample-generator/" not in sys.path:
        sys.path.append("piper-sample-generator/")

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1 \
--batch-size 1 \
--output-dir generated_samples

Audio("generated_samples/0.wav", autoplay=True)

# %%
# Generates a larger amount of wake word samples.
# Start here when trying to improve your model.
# See https://github.com/rhasspy/piper-sample-generator for the full set of
# parameters. In particular, experiment with noise-scales and noise-scale-ws,
# generating negative samples similar to the wake word, and generating many more
# wake word samples, possibly with different phonetic pronunciations.

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1000 \
--batch-size 100 \
--output-dir generated_samples

# %%
# Downloads audio data for augmentation. This can be slow!
# Borrowed from openWakeWord's automatic_model_training.ipynb, accessed March 4, 2024
#
# **Important note!** The data downloaded here has a mixture of difference
# licenses and usage restrictions. As such, any custom models trained with this
# data should be considered as appropriate for **non-commercial** personal use only.


import datasets
import scipy
import os

import numpy as np

from pathlib import Path
from tqdm import tqdm

## Download MIR RIR data

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)
    # Save clips to 16-bit PCM wav files
    for row in tqdm(rir_dataset):
        name = row['audio']['path'].split('/')[-1]
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

    fname = "bal_train09.tar"
    out_dir = f"audioset/{fname}"
    link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
    # !wget -O {out_dir} {link}
    # !cd audioset && tar -xf bal_train09.tar

    output_dir = "./audioset_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
    audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(audioset_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset
# https://github.com/mdeff/fma
# (Third-party mchl914 extra small set)

output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    fname = "fma_xs.zip"
    link = "https://huggingface.co/datasets/mchl914/fma_xsmall/resolve/main/" + fname
    out_dir = f"fma/{fname}"
    # !wget -O {out_dir} {link}
    # !cd {output_dir} && unzip -q {fname}

    output_dir = "./fma_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    fma_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("fma/fma_small").glob("**/*.mp3")]})
    fma_dataset = fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(fma_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# %%
# Sets up the augmentations.
# To improve your model, experiment with these settings and use more sources of
# background clips.

from microwakeword.audio.augmentation import Augmentation
from microwakeword.audio.clips import Clips
from microwakeword.audio.spectrograms import SpectrogramGeneration

clips = Clips(input_directory='generated_samples',
              file_pattern='*.wav',
              max_clip_duration_s=None,
              remove_silence=False,
              random_split_seed=10,
              split_count=0.1,
              )
augmenter = Augmentation(augmentation_duration_s=3.2,
                         augmentation_probabilities = {
                                "SevenBandParametricEQ": 0.1,
                                "TanhDistortion": 0.1,
                                "PitchShift": 0.1,
                                "BandStopFilter": 0.1,
                                "AddColorNoise": 0.1,
                                "AddBackgroundNoise": 0.75,
                                "Gain": 1.0,
                                "RIR": 0.5,
                            },
                         impulse_paths = ['mit_rirs'],
                         background_paths = ['fma_16k', 'audioset_16k'],
                         background_min_snr_db = -5,
                         background_max_snr_db = 10,
                         min_jitter_s = 0.195,
                         max_jitter_s = 0.205,
                         )

# %%
# Augment a random clip and play it back to verify it works well

from IPython.display import Audio
from microwakeword.audio.audio_utils import save_clip

random_clip = clips.get_random_clip()
augmented_clip = augmenter.augment_clip(random_clip)
save_clip(augmented_clip, 'augmented_clip.wav')

Audio("augmented_clip.wav", autoplay=True)

# %%
# Augment samples and save the training, validation, and testing sets.
# Validating and testing samples generated the same way can make the model
# benchmark better than it performs in real-word use. Use real samples or TTS
# samples generated with a different TTS engine to potentially get more accurate
# benchmarks.

import os
from mmap_ninja.ragged import RaggedMmap

output_dir = 'generated_augmented_features'

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

splits = ["training", "validation", "testing"]
for split in splits:
  out_dir = os.path.join(output_dir, split)
  if not os.path.exists(out_dir):
      os.mkdir(out_dir)


  split_name = "train"
  repetition = 2

  spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=10,    # Uses the same spectrogram repeatedly, just shifted over by one frame. This simulates the streaming inferences while training/validating in nonstreaming mode.
                                     step_ms=10,
                                     )
  if split == "validation":
    split_name = "validation"
    repetition = 1
  elif split == "testing":
    split_name = "test"
    repetition = 1
    spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=1,    # The testing set uses the streaming version of the model, so no artificial repetition is necessary
                                     step_ms=10,
                                     )

  RaggedMmap.from_generator(
      out_dir=os.path.join(out_dir, 'wakeword_mmap'),
      sample_generator=spectrograms.spectrogram_generator(split=split_name, repeat=repetition),
      batch_size=100,
      verbose=True,
  )

# %%
# Downloads pre-generated spectrogram features (made for microWakeWord in
# particular) for various negative datasets. This can be slow!

output_dir = './negative_datasets'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    link_root = "https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/"
    filenames = ['dinner_party.zip', 'dinner_party_eval.zip', 'no_speech.zip', 'speech.zip']
    for fname in filenames:
        link = link_root + fname

        zip_path = f"negative_datasets/{fname}"
        # !wget -O {zip_path} {link}
        # !unzip -q {zip_path} -d {output_dir}

# %%
# Save a yaml config that controls the training process
# These hyperparamters can make a huge different in model quality.
# Experiment with sampling and penalty weights and increasing the number of
# training steps.

import yaml
import os

config = {}

config["window_step_ms"] = 10

config["train_dir"] = (
    "trained_models/wakeword"
)


# Each feature_dir should have at least one of the following folders with this structure:
#  training/
#    ragged_mmap_folders_ending_in_mmap
#  testing/
#    ragged_mmap_folders_ending_in_mmap
#  testing_ambient/
#    ragged_mmap_folders_ending_in_mmap
#  validation/
#    ragged_mmap_folders_ending_in_mmap
#  validation_ambient/
#    ragged_mmap_folders_ending_in_mmap
#
#  sampling_weight: Weight for choosing a spectrogram from this set in the batch
#  penalty_weight: Penalizing weight for incorrect predictions from this set
#  truth: Boolean whether this set has positive samples or negative samples
#  truncation_strategy = If spectrograms in the set are longer than necessary for training, how are they truncated
#       - random: choose a random portion of the entire spectrogram - useful for long negative samples
#       - truncate_start: remove the start of the spectrogram
#       - truncate_end: remove the end of the spectrogram
#       - split: Split the longer spectrogram into separate spectrograms offset by 100 ms. Only for ambient sets

config["features"] = [
    {
        "features_dir": "generated_augmented_features",
        "sampling_weight": 2.0,
        "penalty_weight": 1.0,
        "truth": True,
        "truncation_strategy": "truncate_start",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/speech",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/dinner_party",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/no_speech",
        "sampling_weight": 5.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    { # Only used for validation and testing
        "features_dir": "negative_datasets/dinner_party_eval",
        "sampling_weight": 0.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "split",
        "type": "mmap",
    },
]

# Number of training steps in each iteration - various other settings are configured as lists that corresponds to different steps
config["training_steps"] = [10000]

# Penalizing weight for incorrect class predictions - lists that correspond to training steps
config["positive_class_weight"] = [1]
config["negative_class_weight"] = [20]

config["learning_rates"] = [
    0.001,
]  # Learning rates for Adam optimizer - list that corresponds to training steps
config["batch_size"] = 128

config["time_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["time_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps
config["freq_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["freq_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps

config["eval_step_interval"] = (
    500  # Test the validation sets after every this many steps
)
config["clip_duration_ms"] = (
    1500  # Maximum length of wake word that the streaming model will accept
)

# The best model weights are chosen first by minimizing the specified minimization metric below the specified target_minimization
# Once the target has been met, it chooses the maximum of the maximization metric. Set 'minimization_metric' to None to only maximize
# Available metrics:
#   - "loss" - cross entropy error on validation set
#   - "accuracy" - accuracy of validation set
#   - "recall" - recall of validation set
#   - "precision" - precision of validation set
#   - "false_positive_rate" - false positive rate of validation set
#   - "false_negative_rate" - false negative rate of validation set
#   - "ambient_false_positives" - count of false positives from the split validation_ambient set
#   - "ambient_false_positives_per_hour" - estimated number of false positives per hour on the split validation_ambient set
config["target_minimization"] = 0.9
config["minimization_metric"] = None  # Set to None to disable

config["maximization_metric"] = "average_viable_recall"

with open(os.path.join("training_parameters.yaml"), "w") as file:
    documents = yaml.dump(config, file)

# %%
# Trains a model. When finished, it will quantize and convert the model to a
# streaming version suitable for on-device detection.
# It will resume if stopped, but it will start over at the configured training
# steps in the yaml file.
# Change --train 0 to only convert and test the best-weighted model.
# On Google colab, it doesn't print the mini-batch results, so it may appear
# stuck for several minutes! Additionally, it is very slow compared to training
# on a local GPU.

# !python -m microwakeword.model_train_eval \
--training_config='training_parameters.yaml' \
--train 1 \
--restore_checkpoint 1 \
--test_tf_nonstreaming 0 \
--test_tflite_nonstreaming 0 \
--test_tflite_nonstreaming_quantized 0 \
--test_tflite_streaming 0 \
--test_tflite_streaming_quantized 1 \
--use_weights "best_weights" \
mixednet \
--pointwise_filters "64,64,64,64" \
--repeat_in_block  "1, 1, 1, 1" \
--mixconv_kernel_sizes '[5], [7,11], [9,15], [23]' \
--residual_connection "0,0,0,0" \
--first_conv_filters 32 \
--first_conv_kernel_size 5 \
--stride 3

# %%
# Downloads the tflite model file. To use on the device, you need to write a
# Model JSON file. See https://esphome.io/components/micro_wake_word for the
# documentation and
# https://github.com/esphome/micro-wake-word-models/tree/main/models/v2 for
# examples. Adjust the probability threshold based on the test results obtained
# after training is finished. You may also need to increase the Tensor arena
# model size if the model fails to load.

from google.colab import files

files.download(f"trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite")
